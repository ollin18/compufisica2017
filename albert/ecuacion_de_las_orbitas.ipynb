# %%
t=collect(0:3:200);

# %%
k=10
# Out:
# 10

# %%
x_0=1
# Out:
# 1

# %%
y_0=1
# Out:
# 1

# %%
x=zero(t);
y=zero(t);

# %%
for i ∈ eachindex(t)
    x=x_0*cos(k*t)
    y=y_0*sin(k*t)
end
# Out:
# WARNING: cos{T <: Number}(x::AbstractArray{T}) is deprecated, use cos.(x) instead.
# Stacktrace:
#  [1] depwarn(::String, ::Symbol) at ./deprecated.jl:70
#  [2] cos(::Array{Int64,1}) at ./deprecated.jl:57
#  [3] macro expansion at ./In[8]:2 [inlined]
#  [4] anonymous at ./<missing>:?
#  [5] include_string(::String, ::String) at ./loading.jl:515
#  [6] include_string(::Module, ::String, ::String) at /opt/julia_packages/.julia/v0.6/Compat/src/Compat.jl:464
#  [7] execute_request(::ZMQ.Socket, ::IJulia.Msg) at /opt/julia_packages/.julia/v0.6/IJulia/src/execute_request.jl:154
#  [8] eventloop(::ZMQ.Socket) at /opt/julia_packages/.julia/v0.6/IJulia/src/eventloop.jl:8
#  [9] (::IJulia.##14#17)() at ./task.jl:335
# while loading In[8], in expression starting on line 1

# %%
using Plots

# %%
pyplot()
# Out:
# Plots.PyPlotBackend()

# %%
plot(x,y,w=1)
title!("Ecuaciones de las obitas, x en y")
xaxis!("Eje de las (x)")
yaxis!("Eje de las (y)")
# Out:
# <img src="data:image/png;base64,..." />

# %%
plot(x,t,w=2)
title!("F (x) en t ")
xaxis!("Eje de las (x)")
yaxis!("Eje de las t (t)")
# Out:
# <img src="data:image/png;base64,..." />

# %%
plot(y,t,w=2)
title!("f (y) en t")
xaxis!("Eje de las (Y)")
yaxis!("Eje de las t (t)")
# Out:
# <img src="data:image/png;base64,..." />
