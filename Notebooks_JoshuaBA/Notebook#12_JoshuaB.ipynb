# %% [markdown]
# <div class="alert alert-success" role="alert">
# <h1>Programación en Julia: Notebook 12 </h1>
# <h2>Facultad de Ciencias, UNAM </h2>
# <h3>Joshua Briones Andrade || Compufísica </h3>
# </div>

# %%
Ti1=0; Tf1=100; Δt=0.125
t1=collect(Ti1:Δt:Tf1);

# %% [markdown]
# **a)** Escribe un programa que arroje como resultado un archivo con los datos de un movimiento rectilíneo uniforme, en un intervalo de tiempo $[t_i,t_f]$ definido por el usuario.
#
# _____________________

# %% [markdown]
# La ecuación que tenemos del MRU es la siguiente:
#
# $$r⃗ (t)=\vec r_0+v⃗t $$
#
# Donde:
#
# $\vec r_0$: es la posición en el tiempo cero con repecto al origen (x,y)
#
# $\vec v$: es la velocidad que es constante
#
# $t$: es el tiempo

# %%
#Definimos nuestra funcion del MRU con las variables de la velocidad, la posicion inicial y el rango de tiempo.
#También nos crea un archivo.csv que se guarda en el directorio donde estemos trabjando.

function MRU(r,v,t)
    R=zeros(t)
    for i in eachindex(t)
        R[i]=(v*t[i])+r
        end
    tabla=hcat(t,R)
    writedlm("MRU.csv", tabla, '|')
    readdlm("MRU.csv", '|')
end
# Out:
# MRU (generic function with 1 method)

# %%
T=MRU(10,3,0:Δt:50)
# Out:
# 401×2 Array{Float64,2}:
#   0.0     10.0
#   0.125   10.375
#   0.25    10.75
#   0.375   11.125
#   0.5     11.5
#   0.625   11.875
#   0.75    12.25
#   0.875   12.625
#   1.0     13.0
#   1.125   13.375
#   1.25    13.75
#   1.375   14.125
#   1.5     14.5
#   ⋮
#  48.625  155.875
#  48.75   156.25
#  48.875  156.625
#  49.0    157.0
#  49.125  157.375
#  49.25   157.75
#  49.375  158.125
#  49.5    158.5
#  49.625  158.875
#  49.75   159.25
#  49.875  159.625
#  50.0    160.0

# %%
using Plots;
gr()
# Out:
# Plots.GRBackend()

# %%
plot(T[1:end,2],T[1:end,1],w=5,label=["r(t)"])
title!("MRU")
xaxis!("Tiempo")
yaxis!("Posición respecto al origen")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip1400">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1400)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip1401">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1400)" points="
# 44.6753,360.065 580.315,360.065 580.315,31.4961 44.6753,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip1402">
#     <rect x="44" y="31" width="537" height="330"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip1402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   116.094,360.065 116.094,31.4961
#   "/>
# ...

# %% [markdown]
# **b)** Escribe un programa que arroje como resultado un archivo con los datos de un movimiento uniformemente acelerado (o caída libre), en un intervalo de tiempo $[t_i,t_f]$ definido por el usuario.
#
# *_______________________*

# %% [markdown]
# Continuamos con la gráfica de tiro vertical :)
# $$ \vec{r}(t)=\vec{r_0} + \vec{v}t + \frac{\vec{a}t^2}{2} $$
#
# Para analizar con respecto a X y a Y lo separamos en sus componentes.
#
# $$ x(t)=x_0 + v_x t + \frac{a_x t^2}{2} $$
#
# $$ y(t)=y_0 + v_y t + \frac{a_y t^2}{2} $$
#
# Como en el tiro vertical solo se maneja la coordenada Y, despreciaremos a X. También la aceleración es una componente particular porque $a_y =-g=- 9.81 \frac{m}{s^2}$ Entonces nuestro modelo seria el siguiente.
# $$ y(t)=y_0 + v_y t - \frac{gt^2}{2} $$
#
# Donde:
#
# $y_0$: es la posición en el tiempo cero con repecto a Y
#
# $v_y$: es la velocidad inicial
#
# $t$: es el tiempo
#
# $g$: es la gravedad

# %%
#Definimos nuestra funcion del tiro vertical con las variables de la velocidad inicial y el rango de tiempo.
#También nos crea un archivo.csv que se guarda en el directorio donde estemos trabjando.
#Suponemos que nuestro Tiro Vertical parte del origen asi que X_0=0 y Y_0=0

function TiroVertical(viy,t)
    Y=zeros(t)
    for i in eachindex(t)
        Y[i]=(viy*t[i])-(9.81*t[i]*t[i])
        end
    tabla=hcat(t,Y)
    writedlm("Tiro_Vertical.csv", tabla, '|')
    readdlm("Tiro_Vertical.csv", '|')
end
# Out:
# TiroVertical (generic function with 1 method)

# %%
T=TiroVertical(300,1:Δt:50)
# Out:
# 393×2 Array{Float64,2}:
#   1.0      290.19
#   1.125    325.084
#   1.25     359.672
#   1.375    393.953
#   1.5      427.928
#   1.625    461.595
#   1.75     494.957
#   1.875    528.012
#   2.0      560.76
#   2.125    593.202
#   2.25     625.337
#   2.375    657.165
#   2.5      688.688
#   ⋮
#  48.625  -8607.17
#  48.75   -8689.08
#  48.875  -8771.29
#  49.0    -8853.81
#  49.125  -8936.64
#  49.25   -9019.77
#  49.375  -9103.21
#  49.5    -9186.95
#  49.625  -9271.0
#  49.75   -9355.36
#  49.875  -9440.03
#  50.0    -9525.0

# %%
gr()
# Out:
# Plots.GRBackend()

# %%
plot(T[1:end,1],T[1:end,2],w=2)
title!("Tiro Vertical")
xaxis!("Tiempo (s)")
yaxis!("Posición en Y (m)")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip1800">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1800)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip1801">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1800)" points="
# 64.7761,360.065 580.315,360.065 580.315,31.4961 64.7761,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip1802">
#     <rect x="64" y="31" width="517" height="330"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   159.467,360.065 159.467,31.4961
#   "/>
# ...

# %% [markdown]
# **c)** Escribe un programa que arroje como resultado un archivo con los datos de un tiro parabolico, en un intervalo de tiempo $[t_i,t_f]$ definido por el usuario.
#
# _______________

# %% [markdown]
# Según el notebook de Ollin, tenemos la siguiente ecuación que rige el moviento del tiro parabólico.
# $$ \textbf{r(t)}=(X_0 + V_{0x} t)\hat{i}+ (Y_0 + V_{0y} t - \frac{g t^2}{2})\hat{j}\qquad(1) $$
# $$ \textbf{V(t)}=V_x + V_y = v_0cos(\theta)\hat{i}+v_0sin(\theta)\hat{j}\qquad(2) $$
#
# Donde:
#
# $ V_x , V_y $: son las respectivas componentes de la velocidad.
#
# $ \theta $: es el angulo de tiro.
#
# $ \hat{i}, \hat{j} $: son los vectores unitarios de X y Y respectivamente.

# %%
#Definimos nuestra funcion del tiro parabolico con las variables del angulo, la velocidad inicial y el rango de tiempo.
#También nos crea un archivo.csv que se guarda en el directorio donde estemos trabjando.
#Suponemos que nuestro Tiro Parabólico parte del origen asi que X_0=0 y Y_0=0

function TiroParabolico(θ,vi,t)
    X=zeros(t)
    Y=zeros(t)
    vix=vi*cos(θ) #Esto lo definimos asi por la ecuación (2)
    viy=vi*sin(θ)
    for i in eachindex(t)
        X[i]=(vix*t[i])
        Y[i]=(viy*t[i])-(9.81*t1[i]*t1[i])/2  #g=9.81 m/s^2
    end
    tabla=hcat(X,Y,t)
    writedlm("Tiro_Parabólico.csv", tabla, '|')
    readdlm("Tiro_Parabólico.csv", '|')
end
# Out:
# TiroParabolico (generic function with 1 method)

# %%
T=TiroParabolico(pi/4,700,t1)
# Out:
# 801×3 Array{Float64,2}:
#      0.0        0.0       0.0
#     61.8718    61.7952    0.125
#    123.744    123.437     0.25
#    185.616    184.926     0.375
#    247.487    246.261     0.5
#    309.359    307.443     0.625
#    371.231    368.472     0.75
#    433.103    429.348     0.875
#    494.975    490.07      1.0
#    556.847    550.639     1.125
#    618.718    611.054     1.25
#    680.59     671.317     1.375
#    742.462    731.426     1.5
#      ⋮
#  48816.9     1106.49     98.625
#  48878.8     1047.34     98.75
#  48940.6      988.045    98.875
#  49002.5      928.595    99.0
#  49064.4      868.991    99.125
#  49126.2      809.235    99.25
#  49188.1      749.324    99.375
#  49250.0      689.261    99.5
#  49311.9      629.044    99.625
#  49373.7      568.674    99.75
#  49435.6      508.151    99.875
#  49497.5      447.475   100.0

# %%
using Plots;
gr()
# Out:
# Plots.GRBackend()

# %%
plot(T[1:end,1],T[1:end,2],w=2,label=["Tiro"])
title!("Tiro Parabólico")
xaxis!("Posición en X")
yaxis!("Posición en Y")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip1600">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1600)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip1601">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1600)" points="
# 64.4442,360.065 580.315,360.065 580.315,31.4961 64.4442,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip1602">
#     <rect x="64" y="31" width="517" height="330"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip1602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   64.4442,360.065 64.4442,31.4961
#   "/>
# ...
